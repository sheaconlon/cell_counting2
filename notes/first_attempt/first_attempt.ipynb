# %%
# Reload our package (for use if modified).
import importlib
importlib.reload(load)
importlib.reload(normalize)
importlib.reload(process)
importlib.reload(batch)
importlib.reload(cnn)
importlib.reload(metrics)

# %%
# Put the project's root directory on our PYTHONPATH.
import sys
sys.path.insert(0, "../..")

# %%
# Import from our package.
from src.preprocessing import load, normalize, process, batch
from src.classification import cnn, metrics

# %%
# Import from other libraries.
import tensorflow as tf
import random
import numpy as np

# %%
# Define the architecture of our net as a list of layers.
layers = [
    cnn.ConvolutionalLayer(5, 9, 1, "VALID", "convlayer"),
    cnn.TransferLayer(lambda x, name: tf.sigmoid(x, name=name), "trans1layer"),
    cnn.FlatLayer("flatlayer"),
    cnn.FullLayer(30, "full1layer"),
    cnn.TransferLayer(lambda x, name: tf.sigmoid(x, name=name), "trans2layer"),
    cnn.FullLayer(10, "full2layer"),
    cnn.TransferLayer(lambda x, name: tf.sigmoid(x, name=name), "trans3layer"),
    cnn.FullLayer(2, "full3layer")
]

# %%
# Construct the net.
sess = tf.Session()
net = cnn.NeuralNet(
    layers,
    lambda labels, predictions: tf.losses.softmax_cross_entropy(
        labels,
        predictions,
        weights=1,
        label_smoothing=0.1,
        scope=None,
        loss_collection=tf.GraphKeys.LOSSES,
        reduction=tf.losses.Reduction.SUM_BY_NONZERO_WEIGHTS
    ),
    {
        "accuracy": metrics.accuracy
    },
    lambda: tf.train.GradientDescentOptimizer(0.01),
    "models/" + "8",
    "nn"  
)
# Out:
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 10, '_session_config': None, '_save_checkpoints_steps': None, '_tf_random_seed': 42114, '_save_summary_steps': 100, '_save_checkpoints_secs': 60, '_model_dir': 'models/8', '_keep_checkpoint_every_n_hours': 1, '_log_step_count_steps': 1000}

# %%
# Load and preprocess training data.
train_images, train_masks = load.load_images_and_masks("data/train", ("1", "10"))
train_images = normalize.smdm_normalize(train_images, 55, "REFLECT")
train_patches, train_classes = process.patchify(train_images, train_masks, 55, 7)
train_classes = process.one_hot_encode(train_classes)
train_input_fn = batch.input_fn(train_patches, train_classes, 2000)

# %%
# Train the net for 5 minutes.
with tf.Session().as_default():
    net.train_duration_(train_input_fn, 300)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.632015, step = 1
# INFO:tensorflow:Loss for final step: 0.632015.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-1
# INFO:tensorflow:Saving checkpoints for 2 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.601626, step = 2
# INFO:tensorflow:Loss for final step: 0.601626.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-2
# INFO:tensorflow:Saving checkpoints for 3 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.569839, step = 3
# INFO:tensorflow:Loss for final step: 0.569839.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-3
# INFO:tensorflow:Saving checkpoints for 4 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.544467, step = 4
# INFO:tensorflow:Loss for final step: 0.544467.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-4
# INFO:tensorflow:Saving checkpoints for 5 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.521598, step = 5
# INFO:tensorflow:Loss for final step: 0.521598.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-5
# INFO:tensorflow:Saving checkpoints for 6 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.503554, step = 6
# INFO:tensorflow:Loss for final step: 0.503554.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-6
# INFO:tensorflow:Saving checkpoints for 7 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.498099, step = 7
# INFO:tensorflow:Loss for final step: 0.498099.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-7
# INFO:tensorflow:Saving checkpoints for 8 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.472732, step = 8
# INFO:tensorflow:Loss for final step: 0.472732.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-8
# INFO:tensorflow:Saving checkpoints for 9 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.460373, step = 9
# INFO:tensorflow:Loss for final step: 0.460373.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-9
# INFO:tensorflow:Saving checkpoints for 10 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.459008, step = 10
# INFO:tensorflow:Loss for final step: 0.459008.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-10
# INFO:tensorflow:Saving checkpoints for 11 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.442286, step = 11
# INFO:tensorflow:Loss for final step: 0.442286.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-11
# INFO:tensorflow:Saving checkpoints for 12 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.428643, step = 12
# INFO:tensorflow:Loss for final step: 0.428643.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-12
# INFO:tensorflow:Saving checkpoints for 13 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.414754, step = 13
# INFO:tensorflow:Loss for final step: 0.414754.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-13
# INFO:tensorflow:Saving checkpoints for 14 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.428838, step = 14
# INFO:tensorflow:Loss for final step: 0.428838.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-14
# INFO:tensorflow:Saving checkpoints for 15 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.397013, step = 15
# INFO:tensorflow:Loss for final step: 0.397013.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-15
# INFO:tensorflow:Saving checkpoints for 16 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.392042, step = 16
# INFO:tensorflow:Loss for final step: 0.392042.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-16
# INFO:tensorflow:Saving checkpoints for 17 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.399507, step = 17
# INFO:tensorflow:Loss for final step: 0.399507.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-17
# INFO:tensorflow:Saving checkpoints for 18 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.378031, step = 18
# INFO:tensorflow:Loss for final step: 0.378031.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-18
# INFO:tensorflow:Saving checkpoints for 19 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.373137, step = 19
# INFO:tensorflow:Loss for final step: 0.373137.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-19
# INFO:tensorflow:Saving checkpoints for 20 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.365447, step = 20
# INFO:tensorflow:Loss for final step: 0.365447.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-20
# INFO:tensorflow:Saving checkpoints for 21 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.357355, step = 21
# INFO:tensorflow:Loss for final step: 0.357355.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-21
# INFO:tensorflow:Saving checkpoints for 22 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.353736, step = 22
# INFO:tensorflow:Loss for final step: 0.353736.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-22
# INFO:tensorflow:Saving checkpoints for 23 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.349829, step = 23
# INFO:tensorflow:Loss for final step: 0.349829.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-23
# INFO:tensorflow:Saving checkpoints for 24 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.36669, step = 24
# INFO:tensorflow:Loss for final step: 0.36669.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-24
# INFO:tensorflow:Saving checkpoints for 25 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.339979, step = 25
# INFO:tensorflow:Loss for final step: 0.339979.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-25
# INFO:tensorflow:Saving checkpoints for 26 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.33361, step = 26
# INFO:tensorflow:Loss for final step: 0.33361.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-26
# INFO:tensorflow:Saving checkpoints for 27 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.35203, step = 27
# INFO:tensorflow:Loss for final step: 0.35203.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-27
# INFO:tensorflow:Saving checkpoints for 28 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.327045, step = 28
# INFO:tensorflow:Loss for final step: 0.327045.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-28
# INFO:tensorflow:Saving checkpoints for 29 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.32063, step = 29
# INFO:tensorflow:Loss for final step: 0.32063.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-29
# INFO:tensorflow:Saving checkpoints for 30 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.346742, step = 30
# INFO:tensorflow:Loss for final step: 0.346742.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-30
# INFO:tensorflow:Saving checkpoints for 31 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.317861, step = 31
# INFO:tensorflow:Loss for final step: 0.317861.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-31
# INFO:tensorflow:Saving checkpoints for 32 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.32183, step = 32
# INFO:tensorflow:Loss for final step: 0.32183.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-32
# INFO:tensorflow:Saving checkpoints for 33 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.328534, step = 33
# INFO:tensorflow:Loss for final step: 0.328534.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-33
# INFO:tensorflow:Saving checkpoints for 34 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.307148, step = 34
# INFO:tensorflow:Loss for final step: 0.307148.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-34
# INFO:tensorflow:Saving checkpoints for 35 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.311393, step = 35
# INFO:tensorflow:Loss for final step: 0.311393.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-35
# INFO:tensorflow:Saving checkpoints for 36 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.331228, step = 36
# INFO:tensorflow:Loss for final step: 0.331228.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-36
# INFO:tensorflow:Saving checkpoints for 37 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.298223, step = 37
# INFO:tensorflow:Loss for final step: 0.298223.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-37
# INFO:tensorflow:Saving checkpoints for 38 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.29632, step = 38
# INFO:tensorflow:Loss for final step: 0.29632.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-38
# INFO:tensorflow:Saving checkpoints for 39 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.300483, step = 39
# INFO:tensorflow:Loss for final step: 0.300483.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-39
# INFO:tensorflow:Saving checkpoints for 40 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.292642, step = 40
# INFO:tensorflow:Loss for final step: 0.292642.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-40
# INFO:tensorflow:Saving checkpoints for 41 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.31733, step = 41
# INFO:tensorflow:Loss for final step: 0.31733.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-41
# INFO:tensorflow:Saving checkpoints for 42 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.29208, step = 42
# INFO:tensorflow:Loss for final step: 0.29208.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-42
# INFO:tensorflow:Saving checkpoints for 43 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.284828, step = 43
# INFO:tensorflow:Loss for final step: 0.284828.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-43
# INFO:tensorflow:Saving checkpoints for 44 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.312224, step = 44
# INFO:tensorflow:Loss for final step: 0.312224.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-44
# INFO:tensorflow:Saving checkpoints for 45 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.280649, step = 45
# INFO:tensorflow:Loss for final step: 0.280649.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-45
# INFO:tensorflow:Saving checkpoints for 46 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.314509, step = 46
# INFO:tensorflow:Loss for final step: 0.314509.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-46
# INFO:tensorflow:Saving checkpoints for 47 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.277909, step = 47
# INFO:tensorflow:Loss for final step: 0.277909.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-47
# INFO:tensorflow:Saving checkpoints for 48 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.290964, step = 48
# INFO:tensorflow:Loss for final step: 0.290964.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-48
# INFO:tensorflow:Saving checkpoints for 49 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.285203, step = 49
# INFO:tensorflow:Loss for final step: 0.285203.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-49
# INFO:tensorflow:Saving checkpoints for 50 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.309654, step = 50
# INFO:tensorflow:Loss for final step: 0.309654.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-50
# INFO:tensorflow:Saving checkpoints for 51 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.275369, step = 51
# INFO:tensorflow:Loss for final step: 0.275369.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-51
# INFO:tensorflow:Saving checkpoints for 52 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.302036, step = 52
# INFO:tensorflow:Loss for final step: 0.302036.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-52
# INFO:tensorflow:Saving checkpoints for 53 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.305514, step = 53
# INFO:tensorflow:Loss for final step: 0.305514.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-53
# INFO:tensorflow:Saving checkpoints for 54 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.269967, step = 54
# INFO:tensorflow:Loss for final step: 0.269967.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-54
# INFO:tensorflow:Saving checkpoints for 55 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.27432, step = 55
# INFO:tensorflow:Loss for final step: 0.27432.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-55
# INFO:tensorflow:Saving checkpoints for 56 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.281067, step = 56
# INFO:tensorflow:Loss for final step: 0.281067.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-56
# INFO:tensorflow:Saving checkpoints for 57 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.301147, step = 57
# INFO:tensorflow:Loss for final step: 0.301147.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-57
# INFO:tensorflow:Saving checkpoints for 58 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.292203, step = 58
# INFO:tensorflow:Loss for final step: 0.292203.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-58
# INFO:tensorflow:Saving checkpoints for 59 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.283433, step = 59
# INFO:tensorflow:Loss for final step: 0.283433.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-59
# INFO:tensorflow:Saving checkpoints for 60 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.261311, step = 60
# INFO:tensorflow:Loss for final step: 0.261311.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-60
# INFO:tensorflow:Saving checkpoints for 61 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.261423, step = 61
# INFO:tensorflow:Loss for final step: 0.261423.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-61
# INFO:tensorflow:Saving checkpoints for 62 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.26488, step = 62
# INFO:tensorflow:Loss for final step: 0.26488.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-62
# INFO:tensorflow:Saving checkpoints for 63 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.255525, step = 63
# INFO:tensorflow:Loss for final step: 0.255525.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-63
# INFO:tensorflow:Saving checkpoints for 64 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.289446, step = 64
# INFO:tensorflow:Loss for final step: 0.289446.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-64
# INFO:tensorflow:Saving checkpoints for 65 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.252651, step = 65
# INFO:tensorflow:Loss for final step: 0.252651.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-65
# INFO:tensorflow:Saving checkpoints for 66 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.255345, step = 66
# INFO:tensorflow:Loss for final step: 0.255345.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-66
# INFO:tensorflow:Saving checkpoints for 67 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.253382, step = 67
# INFO:tensorflow:Loss for final step: 0.253382.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-67
# INFO:tensorflow:Saving checkpoints for 68 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.248543, step = 68
# INFO:tensorflow:Loss for final step: 0.248543.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-68
# INFO:tensorflow:Saving checkpoints for 69 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.250729, step = 69
# INFO:tensorflow:Loss for final step: 0.250729.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-69
# INFO:tensorflow:Saving checkpoints for 70 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.248065, step = 70
# INFO:tensorflow:Loss for final step: 0.248065.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-70
# INFO:tensorflow:Saving checkpoints for 71 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.253734, step = 71
# INFO:tensorflow:Loss for final step: 0.253734.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-71
# INFO:tensorflow:Saving checkpoints for 72 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.267513, step = 72
# INFO:tensorflow:Loss for final step: 0.267513.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-72
# INFO:tensorflow:Saving checkpoints for 73 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.261814, step = 73
# INFO:tensorflow:Loss for final step: 0.261814.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-73
# INFO:tensorflow:Saving checkpoints for 74 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.243295, step = 74
# INFO:tensorflow:Loss for final step: 0.243295.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-74
# INFO:tensorflow:Saving checkpoints for 75 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.246404, step = 75
# INFO:tensorflow:Loss for final step: 0.246404.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-75
# INFO:tensorflow:Saving checkpoints for 76 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.275575, step = 76
# INFO:tensorflow:Loss for final step: 0.275575.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-76
# INFO:tensorflow:Saving checkpoints for 77 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.246621, step = 77
# INFO:tensorflow:Loss for final step: 0.246621.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-77
# INFO:tensorflow:Saving checkpoints for 78 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.238765, step = 78
# INFO:tensorflow:Loss for final step: 0.238765.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-78
# INFO:tensorflow:Saving checkpoints for 79 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.261929, step = 79
# INFO:tensorflow:Loss for final step: 0.261929.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-79
# INFO:tensorflow:Saving checkpoints for 80 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.2827, step = 80
# INFO:tensorflow:Loss for final step: 0.2827.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-80
# INFO:tensorflow:Saving checkpoints for 81 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.238967, step = 81
# INFO:tensorflow:Loss for final step: 0.238967.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-81
# INFO:tensorflow:Saving checkpoints for 82 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.282502, step = 82
# INFO:tensorflow:Loss for final step: 0.282502.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-82
# INFO:tensorflow:Saving checkpoints for 83 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.236397, step = 83
# INFO:tensorflow:Loss for final step: 0.236397.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-83
# INFO:tensorflow:Saving checkpoints for 84 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.249818, step = 84
# INFO:tensorflow:Loss for final step: 0.249818.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-84
# INFO:tensorflow:Saving checkpoints for 85 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.238993, step = 85
# INFO:tensorflow:Loss for final step: 0.238993.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-85
# INFO:tensorflow:Saving checkpoints for 86 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.23614, step = 86
# INFO:tensorflow:Loss for final step: 0.23614.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-86
# INFO:tensorflow:Saving checkpoints for 87 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.236886, step = 87
# INFO:tensorflow:Loss for final step: 0.236886.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-87
# INFO:tensorflow:Saving checkpoints for 88 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.262488, step = 88
# INFO:tensorflow:Loss for final step: 0.262488.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-88
# INFO:tensorflow:Saving checkpoints for 89 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.256726, step = 89
# INFO:tensorflow:Loss for final step: 0.256726.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-89
# INFO:tensorflow:Saving checkpoints for 90 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.241311, step = 90
# INFO:tensorflow:Loss for final step: 0.241311.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-90
# INFO:tensorflow:Saving checkpoints for 91 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.235046, step = 91
# INFO:tensorflow:Loss for final step: 0.235046.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-91
# INFO:tensorflow:Saving checkpoints for 92 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.233536, step = 92
# INFO:tensorflow:Loss for final step: 0.233536.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-92
# INFO:tensorflow:Saving checkpoints for 93 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.234416, step = 93
# INFO:tensorflow:Loss for final step: 0.234416.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-93
# INFO:tensorflow:Saving checkpoints for 94 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.283911, step = 94
# INFO:tensorflow:Loss for final step: 0.283911.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-94
# INFO:tensorflow:Saving checkpoints for 95 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.257724, step = 95
# INFO:tensorflow:Loss for final step: 0.257724.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-95
# INFO:tensorflow:Saving checkpoints for 96 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.228681, step = 96
# INFO:tensorflow:Loss for final step: 0.228681.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-96
# INFO:tensorflow:Saving checkpoints for 97 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.259582, step = 97
# INFO:tensorflow:Loss for final step: 0.259582.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-97
# INFO:tensorflow:Saving checkpoints for 98 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.227821, step = 98
# INFO:tensorflow:Loss for final step: 0.227821.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-98
# INFO:tensorflow:Saving checkpoints for 99 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.231128, step = 99
# INFO:tensorflow:Loss for final step: 0.231128.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-99
# INFO:tensorflow:Saving checkpoints for 100 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.272278, step = 100
# INFO:tensorflow:Loss for final step: 0.272278.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-100
# INFO:tensorflow:Saving checkpoints for 101 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.230299, step = 101
# INFO:tensorflow:Loss for final step: 0.230299.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-101
# INFO:tensorflow:Saving checkpoints for 102 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.283579, step = 102
# INFO:tensorflow:Loss for final step: 0.283579.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-102
# INFO:tensorflow:Saving checkpoints for 103 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.232038, step = 103
# INFO:tensorflow:Loss for final step: 0.232038.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-103
# INFO:tensorflow:Saving checkpoints for 104 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.225524, step = 104
# INFO:tensorflow:Loss for final step: 0.225524.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-104
# INFO:tensorflow:Saving checkpoints for 105 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.232077, step = 105
# INFO:tensorflow:Loss for final step: 0.232077.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-105
# INFO:tensorflow:Saving checkpoints for 106 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.270651, step = 106
# INFO:tensorflow:Loss for final step: 0.270651.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-106
# INFO:tensorflow:Saving checkpoints for 107 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.271418, step = 107
# INFO:tensorflow:Loss for final step: 0.271418.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-107
# INFO:tensorflow:Saving checkpoints for 108 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.291599, step = 108
# INFO:tensorflow:Loss for final step: 0.291599.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-108
# INFO:tensorflow:Saving checkpoints for 109 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.241167, step = 109
# INFO:tensorflow:Loss for final step: 0.241167.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-109
# INFO:tensorflow:Saving checkpoints for 110 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.227082, step = 110
# INFO:tensorflow:Loss for final step: 0.227082.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-110
# INFO:tensorflow:Saving checkpoints for 111 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.2321, step = 111
# INFO:tensorflow:Loss for final step: 0.2321.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-111
# INFO:tensorflow:Saving checkpoints for 112 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.23933, step = 112
# INFO:tensorflow:Loss for final step: 0.23933.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-112
# INFO:tensorflow:Saving checkpoints for 113 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.222352, step = 113
# INFO:tensorflow:Loss for final step: 0.222352.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-113
# INFO:tensorflow:Saving checkpoints for 114 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.241476, step = 114
# INFO:tensorflow:Loss for final step: 0.241476.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-114
# INFO:tensorflow:Saving checkpoints for 115 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.222591, step = 115
# INFO:tensorflow:Loss for final step: 0.222591.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-115
# INFO:tensorflow:Saving checkpoints for 116 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.256117, step = 116
# INFO:tensorflow:Loss for final step: 0.256117.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-116
# INFO:tensorflow:Saving checkpoints for 117 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.226431, step = 117
# INFO:tensorflow:Loss for final step: 0.226431.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-117
# INFO:tensorflow:Saving checkpoints for 118 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.222541, step = 118
# INFO:tensorflow:Loss for final step: 0.222541.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-118
# INFO:tensorflow:Saving checkpoints for 119 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.222096, step = 119
# INFO:tensorflow:Loss for final step: 0.222096.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-119
# INFO:tensorflow:Saving checkpoints for 120 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.237936, step = 120
# INFO:tensorflow:Loss for final step: 0.237936.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-120
# INFO:tensorflow:Saving checkpoints for 121 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.284884, step = 121
# INFO:tensorflow:Loss for final step: 0.284884.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-121
# INFO:tensorflow:Saving checkpoints for 122 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.241366, step = 122
# INFO:tensorflow:Loss for final step: 0.241366.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-122
# INFO:tensorflow:Saving checkpoints for 123 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.222119, step = 123
# INFO:tensorflow:Loss for final step: 0.222119.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-123
# INFO:tensorflow:Saving checkpoints for 124 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.266139, step = 124
# INFO:tensorflow:Loss for final step: 0.266139.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-124
# INFO:tensorflow:Saving checkpoints for 125 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.280564, step = 125
# INFO:tensorflow:Loss for final step: 0.280564.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-125
# INFO:tensorflow:Saving checkpoints for 126 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.227061, step = 126
# INFO:tensorflow:Loss for final step: 0.227061.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-126
# INFO:tensorflow:Saving checkpoints for 127 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.218087, step = 127
# INFO:tensorflow:Loss for final step: 0.218087.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-127
# INFO:tensorflow:Saving checkpoints for 128 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.2189, step = 128
# INFO:tensorflow:Loss for final step: 0.2189.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-128
# INFO:tensorflow:Saving checkpoints for 129 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.27323, step = 129
# INFO:tensorflow:Loss for final step: 0.27323.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-129
# INFO:tensorflow:Saving checkpoints for 130 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.224119, step = 130
# INFO:tensorflow:Loss for final step: 0.224119.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-130
# INFO:tensorflow:Saving checkpoints for 131 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.257292, step = 131
# INFO:tensorflow:Loss for final step: 0.257292.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-131
# INFO:tensorflow:Saving checkpoints for 132 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.268023, step = 132
# INFO:tensorflow:Loss for final step: 0.268023.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-132
# INFO:tensorflow:Saving checkpoints for 133 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.223577, step = 133
# INFO:tensorflow:Loss for final step: 0.223577.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-133
# INFO:tensorflow:Saving checkpoints for 134 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.221358, step = 134
# INFO:tensorflow:Loss for final step: 0.221358.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-134
# INFO:tensorflow:Saving checkpoints for 135 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.290389, step = 135
# INFO:tensorflow:Loss for final step: 0.290389.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-135
# INFO:tensorflow:Saving checkpoints for 136 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.26964, step = 136
# INFO:tensorflow:Loss for final step: 0.26964.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-136
# INFO:tensorflow:Saving checkpoints for 137 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.250653, step = 137
# INFO:tensorflow:Loss for final step: 0.250653.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-137
# INFO:tensorflow:Saving checkpoints for 138 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.217786, step = 138
# INFO:tensorflow:Loss for final step: 0.217786.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-138
# INFO:tensorflow:Saving checkpoints for 139 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.214661, step = 139
# INFO:tensorflow:Loss for final step: 0.214661.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-139
# INFO:tensorflow:Saving checkpoints for 140 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.278147, step = 140
# INFO:tensorflow:Loss for final step: 0.278147.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-140
# INFO:tensorflow:Saving checkpoints for 141 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.219132, step = 141
# INFO:tensorflow:Loss for final step: 0.219132.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-141
# INFO:tensorflow:Saving checkpoints for 142 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.221908, step = 142
# INFO:tensorflow:Loss for final step: 0.221908.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-142
# INFO:tensorflow:Saving checkpoints for 143 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.2448, step = 143
# INFO:tensorflow:Loss for final step: 0.2448.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-143
# INFO:tensorflow:Saving checkpoints for 144 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.215689, step = 144
# INFO:tensorflow:Loss for final step: 0.215689.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-144
# INFO:tensorflow:Saving checkpoints for 145 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.219318, step = 145
# INFO:tensorflow:Loss for final step: 0.219318.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-145
# INFO:tensorflow:Saving checkpoints for 146 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.237253, step = 146
# INFO:tensorflow:Loss for final step: 0.237253.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-146
# INFO:tensorflow:Saving checkpoints for 147 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.265498, step = 147
# INFO:tensorflow:Loss for final step: 0.265498.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-147
# INFO:tensorflow:Saving checkpoints for 148 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.222873, step = 148
# INFO:tensorflow:Loss for final step: 0.222873.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-148
# INFO:tensorflow:Saving checkpoints for 149 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.222834, step = 149
# INFO:tensorflow:Loss for final step: 0.222834.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-149
# INFO:tensorflow:Saving checkpoints for 150 into models/8/model.ckpt.
# INFO:tensorflow:loss = 0.266266, step = 150
# INFO:tensorflow:Loss for final step: 0.266266.

# %%
# Load and preprocess test data.
test_images, test_masks = load.load_images_and_masks("data/test", ("7"))
test_images = normalize.smdm_normalize(test_images, 55, "REFLECT")
test_patches, test_classes = process.patchify(test_images, test_masks, 55, 7)
test_classes = process.one_hot_encode(test_classes)
test_input_fn = batch.input_fn(test_patches, test_classes, 2000, 1)

# %%
# Evaluate the net.
metric_dict = net.evaluate_(test_input_fn)
# Out:
# INFO:tensorflow:Starting evaluation at 2017-10-15-19:04:59
# INFO:tensorflow:Restoring parameters from models/8/model.ckpt-150
# INFO:tensorflow:Finished evaluation at 2017-10-15-19:05:06
# INFO:tensorflow:Saving dict for global step 150: accuracy = 0.997563, global_step = 150, loss = 0.217251

# %%
# Examine the test results.
metric_dict
# Out:
# {'accuracy': 0.99756336, 'global_step': 150, 'loss': 0.21725084}
